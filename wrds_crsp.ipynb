# %%
import wrds

# %%
db = wrds.Connection()
# Out:
# Enter your WRDS username [Andi]:andicu
# Enter your password:········
# WRDS recommends setting up a .pgpass file.
# You can find more info here:
# https://www.postgresql.org/docs/9.5/static/libpq-pgpass.html.
# Loading library list...
# Done

# %%
db.list_libraries()
# Out:
# ['aha_sample',
#  'ahasamp',
#  'audit',
#  'audit_audit_comp',
#  'block',
#  'boardex',
#  'boardex_trial',
#  'calcbench_trial',
#  'calcbnch',
#  'cboe',
#  'centris',
#  'ciq',
#  'ciq_common',
#  'ciqsamp_capstrct',
#  'ciqsamp_common',
#  'ciqsamp_keydev',
#  'ciqsamp_pplintel',
#  'clrvt',
#  'clrvtsmp',
#  'comp',
#  'comp_bank',
#  'comp_bank_daily',
#  'comp_execucomp',
#  'comp_global',
#  'comp_global_daily',
#  'comp_segments_hist',
#  'comp_segments_hist_daily',
#  'comp_urq',
#  'compa',
#  'compb',
#  'compbd',
#  'compdcur',
#  'compg',
#  'compgd',
#  'comph',
#  'compm',
#  'compnad',
#  'compsamp_snapshot',
#  'compseg',
#  'compsegd',
#  'compsnap',
#  'contrib',
#  'contrib_char_returns',
#  'crsp',
#  'crsp_a_ccm',
#  'crsp_a_indexes',
#  'crsp_a_stock',
#  'crsp_a_treasuries',
#  'crspa',
#  'crspm',
#  'djones',
#  'dmef',
#  'doe',
#  'etfg',
#  'etfg_samp',
#  'etfgsamp',
#  'eureka',
#  'eurekahedge_sample',
#  'execcomp',
#  'factsamp_revere',
# ...

# %%
db.list_tables(library="crsp_a_stock")
# Out:
# ['dsf',
#  'mseexchdates',
#  'dseshares',
#  'dsfhdr',
#  'saz_mdel',
#  'saz_ndi',
#  'msfhdr',
#  'dsiy',
#  'saz_mth',
#  'msenames',
#  'msenasdin',
#  'saz_indhdr',
#  'saz_nam',
#  'saz_ds_dly',
#  'stocknames',
#  'msedist',
#  'msi',
#  'dsedist',
#  'saz_mind',
#  'msiy',
#  'saz_dp_dly',
#  'dseexchdates',
#  'saz_dis',
#  'saz_del',
#  'saz_hdr',
#  'msf',
#  'msedelist',
#  'dsedelist',
#  'mseshares',
#  'dseall',
#  'saz_dind',
#  'dsenasdin',
#  'stock_qvards',
#  'mse',
#  'dse',
#  'dsi',
#  'mseall',
#  'dsenames',
#  'saz_shr']

# %%
db.describe_table(library="crsp", table="dsf")
# Out:
# Approximately 93424600 rows in crsp.dsf.
#        name  nullable              type
# 0     cusip      True        VARCHAR(8)
# 1    permno      True  DOUBLE PRECISION
# 2    permco      True  DOUBLE PRECISION
# 3    issuno      True  DOUBLE PRECISION
# 4     hexcd      True  DOUBLE PRECISION
# 5    hsiccd      True  DOUBLE PRECISION
# 6      date      True              DATE
# 7     bidlo      True  DOUBLE PRECISION
# 8     askhi      True  DOUBLE PRECISION
# 9       prc      True  DOUBLE PRECISION
# 10      vol      True  DOUBLE PRECISION
# 11      ret      True  DOUBLE PRECISION
# 12      bid      True  DOUBLE PRECISION
# 13      ask      True  DOUBLE PRECISION
# 14   shrout      True  DOUBLE PRECISION
# 15   cfacpr      True  DOUBLE PRECISION
# 16  cfacshr      True  DOUBLE PRECISION
# 17  openprc      True  DOUBLE PRECISION
# 18   numtrd      True  DOUBLE PRECISION
# 19     retx      True  DOUBLE PRECISION

# %%
db.get_table(library="crsp", table="dsf", obs=100)

#db.raw_sql('select permno,caldt,prc,valid from crsp.crsp_daily_data LIMIT 100')
# Out:
#        cusip   permno   permco   issuno  hexcd  hsiccd        date      bidlo  \
# 0   84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-09  20.370001
# 1   84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-10  20.400000
# 2   84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-13  20.230000
# 3   84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-14  20.200001
# 4   84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-15  21.530001
# 5   84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-16  22.090000
# 6   84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-17  21.270000
# 7   84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-20  21.040001
# 8   84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-21  21.459999
# 9   84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-22  21.410000
# 10  84721510  88568.0  38463.0  27622.0    3.0  5140.0  2006-11-24  19.379999
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /Applications/anaconda3/envs/myenv/lib/python3.5/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1192                         parameters,
# -> 1193                         context)
#    1194         except BaseException as e:
#
# /Applications/anaconda3/envs/myenv/lib/python3.5/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     508     def do_execute(self, cursor, statement, parameters, context=None):
# --> 509         cursor.execute(statement, parameters)
#     510
#
# ProgrammingError: permission denied for relation cap
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# ...

# %%
db.load_library_list()
# Out:
# Loading library list...
# Done

# %%
db.insp
